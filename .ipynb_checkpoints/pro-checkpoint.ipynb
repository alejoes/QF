# %%
import pandas as pd
import os
import csv
import re

# %%
path_=open("DataEngineerDataSet.csv","r")

# %%
csvF_=csv.reader(path_,delimiter=",")
next(csvF_)
rows=[r for r in csvF_]

# %%
rows[2][21]
# Out:
# '1909–27'

# %%
new_rows=[]
garb=[]
final1 = []
for i in range(0,len(rows)):
    object_=rows[i][0].split(".")
    if len(object_)>2:
        new_rows.append(rows[i])

# %%
for y in range(0,len(new_rows)):
    object2 = new_rows[y][0].split(".")
    if object2[0].isdigit()==True and object2[1].isdigit()==True and object2[2].isdigit()==True:
        final1.append(new_rows[y])

# %%
final2=[]
for y in range(0,len(final1)):
    result = re.split('–| ', final1[y][21])
    if len(result)<3:
        final2.append(final1[y])

# %%
final3=[]
for y in range(0,len(final2)):
    result=re.split("–| ", final2[y][21])
#     result=final2[y][21].split("–")
    if len(result)<2 and result[0].isdigit()==True:
        numb1=result[0]
        numb2=result[0]
        final2[y].insert(22,numb1)
        final2[y].insert(23,numb2)
    
        final3.append(final2[y])

    if len(result)>1 and result[0].isdigit()==True and result[1].isdigit()==True:
        numb1=(result[0])
        if len(result[1])<4:
            numb2=result[0][0]+result[0][1]+result[1]
        else:
            numb2=result[1]
        final2[y].insert(22,numb1)    
        final2[y].insert(23,numb2)
        final3.append(final2[y])
        
for z in range(0,len(final2)):
#     result=re.split("–| ", final2[y][21])
    results=final2[z][21].split(" ")
    if results[0]=="ca." and results[1].isdigit()==True:
        numb2=results[1]
        numb1=int(results[1])-3
        final2[z].insert(22,numb1)
        final2[z].insert(23,numb2)
        final3.append(final2[z])

# %%
len(final3)
# Out:
# 11875

# %%
final3[0]
# Out:
# ['1979.486.1',
#  'FALSE',
#  'FALSE',
#  '1',
#  'The American Wing',
#  'Coin',
#  'One-dollar Liberty Head Coin',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Maker',
#  '',
#  'James Barton Longacre',
#  'American, Delaware County, Pennsylvania 1794–1869 Philadelphia, Pennsylvania',
#  '',
#  'Longacre, James Barton',
#  'American',
#  '1794',
#  '1869',
#  '1853',
#  '1853',
#  '1853',
#  'Gold',
#  'Dimensions unavailable',
#  'Gift of Heinz L. Stoppelmann, 1979',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Metal',
#  '',
#  'http://www.metmuseum.org/art/collection/search/1',
#  '',
#  'Metropolitan Museum of Art, New York, NY',
#  '']

# %%
df = pd.DataFrame.from_records(final2)
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                     0      1      2      3                  4   \
# 0           1979.486.1  FALSE  FALSE      1  The American Wing
# 1           1980.264.5  FALSE  FALSE      2  The American Wing
# 2             67.265.9  FALSE  FALSE      3  The American Wing
# 3            67.265.10  FALSE  FALSE      4  The American Wing
# 4            67.265.11  FALSE  FALSE      5  The American Wing
# 5            67.265.12  FALSE  FALSE      6  The American Wing
# 6            67.265.13  FALSE  FALSE      7  The American Wing
# 7            67.265.14  FALSE  FALSE      8  The American Wing
# 8            67.265.15  FALSE  FALSE      9  The American Wing
# 9           1979.486.3  FALSE  FALSE     10  The American Wing
# 10          1979.486.2  FALSE  FALSE     11  The American Wing
# 11          1979.486.7  FALSE  FALSE     12  The American Wing
# 12          1979.486.4  FALSE  FALSE     13  The American Wing
# 13          1979.486.5  FALSE  FALSE     14  The American Wing
# ...

# %%
x=0
for row in final2:
    x=x+1
    print(x,row[21])
# Out:
# 1 1853
# 2 1901
# 3 1909–27
# 4 1909–27
# 5 1909–27
# 6 1909–27
# 7 1909–27
# 8 1909–27
# 9 1909–27
# 10 1912
# 11 1907
# 12 1876
# 13 1910
# 14 1907
# 15 1665–1700
# 16 1800–1900
# 17 1867
# 18 1860
# 19 1859
# 20 1860
# 21 1859
# 22 1881
# 23 1878
# 24 1860–70
# 25 1860–70
# 26 1860–70
# 27 1860–70
# 28 1860–70
# 29 1860–70
# 30 1885
# 31 1885
# 32 1866
# 33 1847–50
# 34 ca. 1785
# 35 ca. 1785
# 36 1770–1800
# 37 1830–70
# 38 1850–70
# 39 1795–1810
# 40 1795–1810
# 41 ca. 1800
# 42 ca. 1800
# 43 1795–1810
# 44 1795–1810
# 45 1760–80
# 46 1760–80
# 47 1750–65
# 48 1750–65
# 49 1750–80
# 50 1750–80
# 51 1770–1800
# 52 1770–1800
# 53 1740–60
# 54 1740–60
# 55 ca. 1700
# 56 ca. 1700
# 57 1760–80
# 58 1760–80
# 59 1800–1850
# 60 1800–1850
# 61 1730–70
# 62 1730–70
# 63 1770–1800
# 64 1770–1800
# 65 1770–1830
# 66 1770–1830
# 67 1795–1815
# 68 1795–1815
# 69 1700–1800
# 70 1700–1800
# 71 1700–1800
# 72 1700–1800
# 73 1800–1900
# 74 1800–1900
# 75 1700–1800
# 76 1700–1800
# 77 1700–1800
# ...
